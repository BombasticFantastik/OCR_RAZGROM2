# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.imshow(train_dataset[5]['img'].permute(1,2,0).numpy())
#
# NameError: name 'train_dataset' is not defined

# %%
from Loop.Dataset import Images_Dataset,TestImages_Dataset
from Loop.Model import CRNN,Resnet50_CRNN,Resnet_Block
from Loop.Loop import train_loop

from torch.utils.data import DataLoader
import yaml
import torch.nn as nn 
import os
import torch

import torch.optim as optim

option_path='config.yml'
with open(option_path,'r') as file_option:
    option=yaml.safe_load(file_option)

device=option['device']

train_dataset=Images_Dataset(option['path'])

# %%
import matplotlib.pyplot as plt
plt.imshow(train_dataset[50]['img'].permute(1,2,0).numpy())

# %%
import torchvision

# %%
torchvision.models.resnet.resnet50
# Out:
# <function torchvision.models.resnet.resnet50(*, weights: Optional[torchvision.models.resnet.ResNet50_Weights] = None, progress: bool = True, **kwargs: Any) -> torchvision.models.resnet.ResNet>
